# %%
# Step 1: Define Word Vectors
word_vectors = {}

for i in range(4):  # Limiting to 4 words for simplicity
    word = input(f"🌟 Enter word {i + 1}: ")
    x = float(input(f"Enter x value for {word}: "))
    y = float(input(f"Enter y value for {word}: "))
    word_vectors[word] = [x, y]

print("\n Word Vectors:", word_vectors)
# Out:
# 🌟 Enter word 1:  hawk
# Enter x value for hawk:  2
# Enter y value for hawk:  4
# 🌟 Enter word 2:  turtle
# Enter x value for turtle:  1
# Enter y value for turtle:  3
# 🌟 Enter word 3:  car
# Enter x value for car:  5
# Enter y value for car:  3
# 🌟 Enter word 4:  priest
# Enter x value for priest:  2
# Enter y value for priest:  7
#  Word Vectors: {'hawk': [2.0, 4.0], 'turtle': [1.0, 3.0], 'car': [5.0, 3.0], 'priest': [2.0, 7.0]}

# %%
import matplotlib.pyplot as plt

# Step 2: Visualizing Word Vectors
def plot_word_vectors(word_vectors):
    for word, vector in word_vectors.items():
        plt.scatter(vector[0], vector[1])
        plt.text(vector[0] + 0.1, vector[1], word, fontsize=12)

    plt.title('📌 Word Vector Space (2D)')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.grid()
    plt.show()

plot_word_vectors(word_vectors)
# Out:
# /Users/arnoldm./.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

# Step 3: Cosine Similarity Calculation
def cosine_similarity(vector1, vector2):
    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)
    return dot_product / (magnitude1 * magnitude2)

# Get user input for two words to compare
word1 = input("🔍 Enter the first word to compare: ")
word2 = input("🔍 Enter the second word to compare: ")

# Calculate and print cosine similarity
if word1 in word_vectors and word2 in word_vectors:
    similarity = cosine_similarity(word_vectors[word1], word_vectors[word2])
    print(f"\n📏 Cosine similarity between '{word1}' and '{word2}': {similarity:.4f}")
else:
    print("⚠️ One of the words is not in the word vector dictionary.")
# Out:
# 🔍 Enter the first word to compare:  turtle
# 🔍 Enter the second word to compare:  hawk
# 📏 Cosine similarity between 'turtle' and 'hawk': 0.9899

# %%
# 3D space now:
from mpl_toolkits.mplot3d import Axes3D

# Step 4: Define 3D Word Vectors
word_vectors_3d = {}

for i in range(4):
    word = input(f"🌟 Enter word {i + 1}: ")
    x = float(input(f"Enter x value for {word}: "))
    y = float(input(f"Enter y value for {word}: "))
    z = float(input(f"Enter z value for {word}: "))
    word_vectors_3d[word] = [x, y, z]

# Step 4: Visualizing 3D Word Vectors
def plot_word_vectors_3d(word_vectors_3d):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    for word, vector in word_vectors_3d.items():
        ax.scatter(vector[0], vector[1], vector[2])
        ax.text(vector[0], vector[1], vector[2], word, fontsize=12)

    ax.set_title('🌍 Word Vector Space (3D)')
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_zlabel('Dimension 3')
    plt.show()

plot_word_vectors_3d(word_vectors_3d)
# Out:
# 🌟 Enter word 1:  snail
# Enter x value for snail:  1
# Enter y value for snail:  1.5
# Enter z value for snail:  0.5
# 🌟 Enter word 2:  human
# Enter x value for human:  2
# Enter y value for human:  3
# Enter z value for human:  5
# 🌟 Enter word 3:  curtain
# Enter x value for curtain:  7
# Enter y value for curtain:  5
# Enter z value for curtain:  9
# 🌟 Enter word 4:  pokemon
# Enter x value for pokemon:  8
# Enter y value for pokemon:  1
# Enter z value for pokemon:  2
# /Users/arnoldm./.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Step 5: Cosine Similarity in 3D
def cosine_similarity_3d(vector1, vector2):
    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)
    return dot_product / (magnitude1 * magnitude2)

# Get user input for two words to compare in 3D
word1 = input("🔍 Enter the first word to compare (3D): ")
word2 = input("🔍 Enter the second word to compare (3D): ")

# Calculate and print cosine similarity for 3D vectors
if word1 in word_vectors_3d and word2 in word_vectors_3d:
    similarity = cosine_similarity_3d(word_vectors_3d[word1], word_vectors_3d[word2])
    print(f"\n📏 Cosine similarity between '{word1}' and '{word2}' in 3D: {similarity:.4f}")
else:
    print("⚠️ One of the words is not in the 3D word vector dictionary.")
# Out:
# 🔍 Enter the first word to compare (3D):  snail
# 🔍 Enter the second word to compare (3D):  curtain
# 📏 Cosine similarity between 'snail' and 'curtain' in 3D: 0.8157

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


word_vectors_3d = {}

for i in range(5):
    word = input(f"🌟 Enter word {i + 1}: ")
    x = float(input(f"Enter x value for {word}: "))
    y = float(input(f"Enter y value for {word}: "))
    z = float(input(f"Enter z value for {word}: "))
    word_vectors_3d[word] = [x, y, z]

# Step 4: Visualizing 3D Word Vectors
def plot_word_vectors_3d(word_vectors_3d):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    for word, vector in word_vectors_3d.items():
        ax.scatter(vector[0], vector[1], vector[2])
        ax.text(vector[0], vector[1], vector[2], word, fontsize=12)

    ax.set_title('🌍 Word Vector Space (3D)')
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_zlabel('Dimension 3')
    plt.show()

plot_word_vectors_3d(word_vectors_3d)
# Out:
# 🌟 Enter word 1:  cat
# Enter x value for cat:  1
# Enter y value for cat:  2
# Enter z value for cat:  3
# 🌟 Enter word 2:  fox
# Enter x value for fox:  1.1
# Enter y value for fox:  2.1
# Enter z value for fox:  3.1
# 🌟 Enter word 3:  carpet
# Enter x value for carpet:  10
# Enter y value for carpet:  12
# Enter z value for carpet:  14
# 🌟 Enter word 4:  matt
# Enter x value for matt:  20
# Enter y value for matt:  15
# Enter z value for matt:  17
# 🌟 Enter word 5:  cigar
# Enter x value for cigar:  20
# Enter y value for cigar:  25
# Enter z value for cigar:  30
# /Users/arnoldm./.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

def cosine_similarity_3d(vector1, vector2):
    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)
    return dot_product / (magnitude1 * magnitude2)


words = list(word_vectors_3d.keys())
 
for i in range(len(words)):  
    for j in range(i + 1, len(words)):  # Compare each word pair once
        word1, word2 = words[i], words[j]
        similarity = cosine_similarity_3d(word_vectors_3d[word1], word_vectors_3d[word2])
        
        print(f"📏 Cosine similarity between '{word1}' and '{word2}': {similarity:.4f}")
# Out:
# 📏 Cosine similarity between 'cat' and 'fox': 0.9999
# 📏 Cosine similarity between 'cat' and 'carpet': 0.9683
# 📏 Cosine similarity between 'cat' and 'matt': 0.8929
# 📏 Cosine similarity between 'cat' and 'cigar': 0.9746
# 📏 Cosine similarity between 'fox' and 'carpet': 0.9724
# 📏 Cosine similarity between 'fox' and 'matt': 0.9001
# 📏 Cosine similarity between 'fox' and 'cigar': 0.9782
# 📏 Cosine similarity between 'carpet' and 'matt': 0.9745
# 📏 Cosine similarity between 'carpet' and 'cigar': 0.9996
# 📏 Cosine similarity between 'matt' and 'cigar': 0.9688
