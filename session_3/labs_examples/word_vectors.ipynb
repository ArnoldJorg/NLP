# %%
import gensim.downloader as api
import numpy as np

# Load pre-trained word vectors - (1 to 1 example by marysia)
word_model = api.load("glove-wiki-gigaword-100")  # 100D word vectors
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
words = ["king", "queen", "man", "woman", "apple", "banana", "cat", "dog"]
word_vectors = np.array([word_model[word] for word in words])

# %%
word_vectors
# Out:
# array([[-3.2307e-01, -8.7616e-01,  2.1977e-01,  2.5268e-01,  2.2976e-01,
#          7.3880e-01, -3.7954e-01, -3.5307e-01, -8.4369e-01, -1.1113e+00,
#         -3.0266e-01,  3.3178e-01, -2.5113e-01,  3.0448e-01, -7.7491e-02,
#         -8.9815e-01,  9.2496e-02, -1.1407e+00, -5.8324e-01,  6.6869e-01,
#         -2.3122e-01, -9.5855e-01,  2.8262e-01, -7.8848e-02,  7.5315e-01,
#          2.6584e-01,  3.4220e-01, -3.3949e-01,  9.5608e-01,  6.5641e-02,
#          4.5747e-01,  3.9835e-01,  5.7965e-01,  3.9267e-01, -2.1851e-01,
#          5.8795e-01, -5.5999e-01,  6.3368e-01, -4.3983e-02, -6.8731e-01,
#         -3.7841e-01,  3.8026e-01,  6.1641e-01, -8.8269e-01, -1.2346e-01,
#         -3.7928e-01, -3.8318e-01,  2.3868e-01,  6.6850e-01, -4.3321e-01,
#         -1.1065e-01,  8.1723e-02,  1.1569e+00,  7.8958e-01, -2.1223e-01,
#         -2.3211e+00, -6.7806e-01,  4.4561e-01,  6.5707e-01,  1.0450e-01,
#          4.6217e-01,  1.9912e-01,  2.5802e-01,  5.7194e-02,  5.3443e-01,
# ...

# %%
# word_vectors = np.array([word_model[word] for word in words])
word_vectors = []

for word in words:
    word_vectors.append(word_model[word])

print(word_vectors)
# Out:
# [array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
# ...

# %%
type(word_vectors[0])
# Out:
# numpy.ndarray
